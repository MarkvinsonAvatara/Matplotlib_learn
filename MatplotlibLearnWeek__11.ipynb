# %% [markdown]
# # Matplotlib Week 11

# %% [markdown]
# # Animasi pada Matplotlib

# %%
#import modules
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation 
from IPython import display
import numpy as np

# %%
#check version
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# # Review figure

# %%
fig=plt.figure()
plt.xlim(0,4)
#limit nilai pada sumbu x (dari 0 s/d 4)
plt.ylim(-2,2)
#limit nilai pada sumbu y (dari -2 s/d 2)

print(plt.plot([]))
# Out:
# <img src="data:image/png;base64,..." width="428">
# ...

# %% [markdown]
# # Animasi pada Matplotlib

# %%
fig=plt.figure()
plt.xlim(0,4)
#limit nilai pada sumbu x (dari 0 s/d 4)
plt.ylim(-2,2)
#limit nilai pada sumbu y (dari -2 s/d 2)

line=plt.plot([])[0]

def animate(i):
    x= np.linspace(0,4,1000)
    y= np.sin(2*np.pi*(x-0.01*i))
    line.set_data(x,y)
    return line

anim=FuncAnimation(fig, animate,frames=200, interval=20)
video=anim.to_html5_video()
html=display.HTML(video)
display.display(html)

plt.close()

# %% [markdown]
# note:
# - jika saat merun code diatas dan terdapat error "ffmpeg not available" kita dapat melihat link ini untuk solusinya:
# https://anaconda.org/conda-forge/ffmpeg
# - Untuk melihat animasinya kalian harus membukanya di jupyter notebook kalian masing

# %% [markdown]
# source: https://www.youtube.com/watch?v=MAV8eJsJzJk
